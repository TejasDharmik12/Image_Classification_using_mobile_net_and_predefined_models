# %%
import tensorflow as tf

# %%
import numpy as np

# %%
filename =  'image_data//hen1.jpg'

# %% [markdown]
# # IPython First Method to load an image

# %%
from IPython.display import Image
Image(filename = 'image_data//hen1.jpg',width=224, height=224)

# %% [markdown]
# # second method to load an image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# # third method to load image

# %%
import cv2

# %%
imgg = cv2.imread(filename)

# %%
imgg = cv2.resize(imgg,(224,224))

# %%
plt.imshow(imgg)   #it is GBR

# %%
plt.imshow(cv2.cvtColor(imgg, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Fourth method to load image

# %%
from PIL import Image

# %%
im = Image.open(filename)

# %%
im = im.resize((224,224))

# %%
plt.imshow(im)

# %% [markdown]
# # Lets load the deep learning model

# %%
mobile = tf.keras.applications.mobilenet.MobileNet() ## deep learning model weights pre-trained

# %%
## Creating a model
##training a model
# test or validate
# predict

# %% [markdown]
# ## Pre-processing of the image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)

# %%
resized_img.shape
# Out:
# (224, 224, 3)

# %%
final_image = np.expand_dims(resized_img,axis=0) #need fourth dimension

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
final_image=tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results = imagenet_utils.decode_predictions(predictions)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 1us/step

# %%
print(results)
# Out:
# [[('n01514668', 'cock', 0.74920815), ('n01514859', 'hen', 0.21982421), ('n02095889', 'Sealyham_terrier', 0.010670342), ('n01855672', 'goose', 0.005222505), ('n02085782', 'Japanese_spaniel', 0.003783172)]]

# %%
plt.imshow(img)

# %%
mobile2 = tf.keras.applications.mobilenet_v2.MobileNetV2() ## deep learning model weights pre-trained
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224.h5
# 14536120/14536120 [==============================] - 1s 0us/step

# %%
predictions = mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 0s 77ms/step

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n01514668', 'cock', 0.74920815), ('n01514859', 'hen', 0.21982421), ('n02095889', 'Sealyham_terrier', 0.010670342), ('n01855672', 'goose', 0.005222505), ('n02085782', 'Japanese_spaniel', 0.003783172)]]

# %%
# anyone = tf.keras.applications.
